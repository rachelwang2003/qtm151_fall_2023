# %% [markdown]
# # <span style="color:darkblue"> QTM 151 - Quiz 1 </span>

# %% [markdown]
# ## Try to submit as an HTML file

# %% [markdown]
# <font size="5">
#
# Print your name below

# %%
# Write your answer here
print('Rachel Wang')
# Out:
# Rachel Wang

# %% [markdown]
# <font size = "5" >
# This quiz is open book
#
# - You can use the lecture notes
# - You will get partial credit for attempting the questions
# - To get full credit, the code should your run as intended
# - You should <span style="color:red"> NOT </span> communicate with other students
#
# Print the following message: <br>
#
# "I will abide by Emory's code of conduct"
#
# **By printing the message, you acknowledge that you will abide by Emory's code of conduct.**

# %%
# Write your answer here:
print("I will abide by Emory's code of conduct")
# Out:
# I will abide by Emory's code of conduct

# %% [markdown]
# <font size = "5">
#
# Import the libraries "numpy", "matplotlib.pytplot", and "pandas"

# %%
# Write your answer here
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ## <span style="color:darkblue"> Part I: Preliminaries </span>

# %% [markdown]
# <font size = "5">
#
# (a) Create two random variables ...
#
#
# - Call them "vec_x" and "vec_z"
# - Generate "vec_x" from a uniform distribution with (low = 10, high = 20, size = 1000)
# - Generate "vec_z" from a uniform distribution with (low = -2, high = 5, size = 1000)
# - Plot a histogram of each variable
#     - Label the axes and title
#     - Each graph should have a different title
#
# To get full points, plot the histograms on a grid (See Lecture 6)

# %%
# Write your answer here:
vec_x    = np.random.uniform(low = 10,high = 20, size = 1000)
vec_z    = np.random.uniform(low = -2,high = 5, size = 1000)
fig, list_subfig = plt.subplots(1, 2,figsize = (6,3))
list_subfig[0].hist(x = vec_x)
list_subfig[0].set_title("Uniform Distribution of Vector X")
list_subfig[0].set_xlabel("Value")
list_subfig[0].set_ylabel("Frequency")

list_subfig[1].hist(x = vec_z)
list_subfig[1].set_title("Uniform Distribution of Vector Z")
list_subfig[1].set_xlabel("Value")
list_subfig[1].set_ylabel("Frequency")
# Out:
# Text(0, 0.5, 'Frequency')

# %% [markdown]
# <font size = "5">
#
# (b) Create a new variable "vec_y" by the formula
#
# $ y = e^x + 2x + 5$
#
# - Use element-by-element vector operations (no loops)
# - Produce a scatter plot of "vec_y" against "vec_x"
# - Label the axes and the title
# - Change the color to "red", "green" or "purple" (you choose)
#
# Hint: You can use the numpy "exp()" function with vector arrays

# %%
# Write your answer here:
vec_y = np.exp(vec_x) + 2 * vec_x + 5
print(vec_y)

plt.scatter(vec_x, vec_y, color = "red")
plt.xlabel("X-axis")
plt.ylabel("Y-axis")
plt.title("Vector X by Vector Y")
# Out:
# [1.50162416e+05 2.59625883e+07 2.71460842e+07 1.22408645e+07
#  3.73910741e+07 9.57229036e+07 2.35390939e+07 2.75697455e+06
#  4.02239713e+08 6.52745780e+05 7.21567377e+06 8.11344840e+05
#  2.60728712e+07 3.97758848e+07 8.79462107e+07 6.12713483e+04
#  4.53279114e+07 3.12249320e+08 7.38946058e+07 8.33711934e+06
#  1.84536223e+07 2.90187102e+07 1.58248797e+06 2.21720216e+04
#  2.45607421e+06 9.76681081e+04 3.21066828e+05 8.36074095e+07
#  8.98722243e+04 7.11206967e+06 5.05210253e+04 1.09750004e+08
#  1.06222185e+07 3.69027077e+05 5.13425586e+07 1.24778467e+07
#  9.07675346e+06 2.74853127e+04 3.42014236e+07 3.40369989e+04
#  8.39466880e+07 5.85610776e+06 1.21151977e+05 2.83040052e+04
#  4.57483075e+07 3.86317108e+04 1.36741885e+06 3.37605406e+06
#  1.76219706e+05 6.68660015e+04 1.92613895e+06 3.76130200e+07
#  3.79286425e+05 4.64210190e+04 8.24180806e+07 1.40513529e+08
#  1.76188018e+07 2.54708191e+07 7.06101239e+07 1.94952414e+08
#  1.06663134e+08 7.46110751e+04 2.23613999e+04 1.29782135e+08
#  2.14687266e+08 7.56594825e+07 4.11277557e+05 3.51428819e+05
#  2.01932889e+05 4.77680838e+04 1.24615753e+08 3.34049190e+08
#  1.08363346e+08 1.11276055e+05 6.06787127e+05 4.83617916e+07
#  1.67236357e+05 3.99348828e+05 1.55624568e+06 9.93714847e+06
#  1.82057564e+06 4.36343303e+05 5.06116944e+04 3.03627345e+06
#  1.33336132e+07 3.28400050e+04 1.61489709e+07 1.96772815e+08
#  1.23696919e+05 1.35346627e+07 2.87138075e+04 7.09615792e+06
#  2.69965851e+07 2.51938336e+06 1.33099793e+06 2.08597412e+08
#  3.43078275e+05 4.63878486e+06 2.88634742e+05 7.04023967e+04
#  2.66681516e+08 1.77452053e+05 3.09676936e+04 3.71573829e+07
#  1.07048146e+07 3.35198104e+08 2.72554308e+08 3.09137009e+04
#  1.00106599e+07 4.16024022e+05 1.69123931e+06 1.12095985e+07
#  5.41942190e+07 2.88138376e+04 2.31711204e+08 4.91094024e+06
#  4.40616165e+05 1.24813267e+06 3.59109171e+07 1.71884937e+07
#  4.82367775e+08 2.85807049e+08 2.87779400e+04 2.08842815e+07
#  1.29412761e+06 1.42338104e+07 6.49635898e+04 4.84955133e+08
#  8.67928653e+06 3.41116366e+07 4.98969200e+04 1.70385189e+05
#  7.58496670e+04 9.57885232e+07 2.04122022e+08 3.74131486e+07
#  7.62459911e+04 2.94087860e+07 1.32704629e+07 3.02154814e+07
#  1.29964718e+06 1.05220850e+08 3.56637958e+04 7.82393298e+05]
# Text(0.5, 1.0, 'Vector X by Vector Y')

# %% [markdown]
# <font size = "5">
#
# (c) Create two lists with ...
#
# - The names of the datasets
# - The years of the datasets (type manually based on the dataset names)
#
# To answer this question, you need to browse the Quiz folder
#
# You will find three datasets on the distribution of ages worldwide

# %%
# Write your own code
year_list = [1980, 2000, 2020]

# %% [markdown]
# <font size = "5">
#
# (d) Create a loop that ...
#
#
# - Goes over the list of years
# - If the year $\ge$ 2008, print the message
#
# $\qquad$ "This dataset contains information on or after 2008.
#
# - If the year $<$ 2008, print the message
#
# $\qquad$ "This dataset contains information before 2008"

# %%
# Write your own code
for i in year_list:
    if i >= 2008:
        print('This dataset contains information on or after 2008')
    else:
        print('This dataset contains information before 2008')
# Out:
# This dataset contains information before 2008
# This dataset contains information before 2008
# This dataset contains information on or after 2008

# %% [markdown]
# <font size = "5">
#
# (e) Your goal is to convert all the ".csv" data files to ".xlsx" (Excel) files
#
# <font size = "4">
#
# - **Before answering** this question do use your terminal (in Mac) or Anaconda prompt (in windows) to install the following package: ```conda install openpyxl```
# - Create a list with the ".csv" dataset names (including their relative subfolder "data_quiz/)
# - Create a new list called "list_newnames", with each element ending in ".xlsx" (including the subfolder "data_excel/")
# - Start an index
#
# $\qquad$ index = 0
#
# - Initiate a for loop over the list of dataset names. Inside the loop:
#     - Read the ".csv" dataset and store it in an object called "dataset"
#     - Create a variable called "filename" from the "list_newnames", extracting the element "index"
#     - Store "dataset" as an excel file with name "filename".
#
#     $\qquad$ index = index + 1
#
# Note: Check that you did it correctly by trying to open your new excel files outside "VSCode"

# %%
# Write your own code

# %% [markdown]
# <font size = "5">
#
# (f) Your goal is to open each dataset, create a new variable, then plot
#
#
# <font size = "3">
#
# - Create a list with the ".csv" dataset names (including their relative subfolder "data_quiz/)
# - Start an index
#
# $\qquad$ index = 0
#
# - Initiate a for loop over the list of dataset names. Inside the loop:
#     - Read the dataset and store it in an object called "dataset"
#     - Create two new variables as
#
#     $\qquad$ percent_ages0to14 = dataset["percent_ages0to14"] <br>
#
#     - Calculate the proportion of the population 15 or older by computing "100 -  percent_ages0to14".
#     - Plot a histogram and label the axes
#     - Use plt.show() to display the plot
#     - Write
#
#     $\qquad$ index = index + 1
#
#
# This should produce a histogram for each dataset

# %%
# Write your own code:
